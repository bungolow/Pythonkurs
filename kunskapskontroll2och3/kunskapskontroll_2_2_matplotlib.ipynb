# %% [markdown]
# # Matplotlib
# Read the links https://matplotlib.org/stable/users/explain/quick_start.html and https://matplotlib.org/stable/tutorials/pyplot.html before starting the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
print("Either the object oriented approach or the pyplot (implicit) approch")
print("The recommended approach is the object oriented apporach")
# Out:
# Either the object oriented approach or the pyplot (implicit) approch
# The recommended approach is the object oriented apporach

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
print("A Matplotlib-diagram is drawn as an object called Figure")
print(" The diagram itself is drawn on an object called Axes. A Figure can have one or more Axes")
print("Axis is the vertical and horizontal lines in a diagram, like the x and y axis")
print("An artist is any object that can be drawn on the Figure")
# Out:
# A Matplotlib-diagram is drawn as an object called Figure
#  The diagram itself is drawn on an object called Axes. A Figure can have one or more Axes
# Axis is the vertical and horizontal lines in a diagram, like the x and y axis
# An artist is any object that can be drawn on the Figure

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
print("Arrays like Numpy arrays, Pyton lists or tuples. Matplotlib then converts the input to Numpy array and expects input data that can be interpreted as numeric or datetime sequences")
# Out:
# Arrays like Numpy arrays, Pyton lists or tuples. Matplotlib then converts the input to Numpy array and expects input data that can be interpreted as numeric or datetime sequences

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
x = np.linspace(-4 , 4, 100)
y = x**2

fig , ax = plt.subplots()
ax.plot(x,y)
ax.set_title('y = x^2')
ax.set_xlabel('x')
ax.set_ylabel('y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
fig, ax = plt.subplots(figsize = (9,3) )
ax.scatter(random_data_x, random_data_y)
ax.set(title='Fruits' , xlabel='fruits' , ylabel= 'Number of fruits')
# Out:
# [Text(0.5, 1.0, 'Fruits'),
#  Text(0.5, 0, 'fruits'),
#  Text(0, 0.5, 'Number of fruits')]

# %%
fig, ax = plt.subplots(figsize = (9,3))
ax.set(title='Fruits' , xlabel='fruits' , ylabel= 'Number of fruits')
ax.bar(x=names, height=values)
# Out:
# <BarContainer object of 5 artists>
